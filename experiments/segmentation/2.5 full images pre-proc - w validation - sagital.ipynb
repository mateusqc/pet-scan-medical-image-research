# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from dataclasses import dataclass
import pathlib

# %%
@dataclass(frozen=True)
class DatasetConfig:
    SEED_VALUE:  int = 41
    CUT_PLANE:   str = "sagital"
         
    DATA_ROOT_SOURCE_PATH: str = '/home/jovyan/data/auto-pet-iii/2024-05-10_Autopet_v1.1'
    MAIN_DATA_CSV_PATH: str = DATA_ROOT_SOURCE_PATH + '/fdg_metadata.csv'
    DATA_ROOT_TARGET:  str = f'/home/jovyan/data/segmentation/autopet-full-{CUT_PLANE}' 
    DATA_ROOT_TRAIN:  str = DATA_ROOT_TARGET + '/Train' 
    DATA_ROOT_VALID:  str = DATA_ROOT_TARGET + '/Valid'
    DATA_ROOT_TEST:   str = DATA_ROOT_TARGET + '/Test'
    DATA_TEST_GT:     str = DATA_ROOT_TARGET + '/Test.csv'

# %%
# train, val and test split

# %%
data_df = pd.read_csv(DatasetConfig.DATA_ROOT_TARGET + "/data_description.csv")
data_df
# Out:
#        Unnamed: 0        Subject ID  \
# 0               0  PETCT_f21755a99b
# 1               1  PETCT_f21755a99b
# 2               2  PETCT_f21755a99b
# 3               3  PETCT_f21755a99b
# 4               4  PETCT_f21755a99b
# ...           ...               ...
# 30740       30740  PETCT_3ba0277c0c
# 30741       30741  PETCT_3ba0277c0c
# 30742       30742  PETCT_3ba0277c0c
# 30743       30743  PETCT_3ba0277c0c
# 30744       30744  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis condition  \
# 0      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# ...                                                  ...       ...       ...
# 30740  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30741  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30742  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30743  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30744  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 0           157          400
# 1           158          400
# 2           159          400
# 3           160          400
# 4           161          400
# ...         ...          ...
# 30740       270          400
# 30741       271          400
# 30742       272          400
# 30743       273          400
# 30744       274          400
#
#                                                imagePath  \
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# ...                                                  ...     ...    ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
#
# [30745 rows x 11 columns]

# %%
data_df.diagnosis.value_counts()
# Out:
# diagnosis
# POSITIVE    30745
# Name: count, dtype: int64

# %%
col_names = data_df.columns.to_list()
col_names[0] = "imageId"
col_names
# Out:
# ['imageId',
#  'Subject ID',
#  'Study UID',
#  'diagnosis',
#  'condition',
#  'sliceNum',
#  'totalSlices',
#  'imagePath',
#  'segPath',
#  'height',
#  'width']

# %%
data_df.columns = col_names
data_df.head()
# Out:
#    imageId        Subject ID  \
# 0        0  PETCT_f21755a99b
# 1        1  PETCT_f21755a99b
# 2        2  PETCT_f21755a99b
# 3        3  PETCT_f21755a99b
# 4        4  PETCT_f21755a99b
#
#                                            Study UID diagnosis condition  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
#
#    sliceNum  totalSlices                                          imagePath  \
# 0       157          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1       158          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2       159          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3       160          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4       161          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                              segPath  height  width
# 0  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 1  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 2  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 3  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 4  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400

# %%
# new height will be based on the mean value
data_df.height.describe()
# Out:
# count    30745.000000
# mean       343.396455
# std         91.927632
# min        242.000000
# 25%        284.000000
# 50%        326.000000
# 75%        326.000000
# max        661.000000
# Name: height, dtype: float64

# %%
data_df[data_df.height > 395]
# Out:
#        imageId        Subject ID  \
# 188        188  PETCT_7ce196485f
# 189        189  PETCT_7ce196485f
# 190        190  PETCT_7ce196485f
# 191        191  PETCT_7ce196485f
# 192        192  PETCT_7ce196485f
# ...        ...               ...
# 30169    30169  PETCT_4776e75543
# 30170    30170  PETCT_4776e75543
# 30171    30171  PETCT_4776e75543
# 30172    30172  PETCT_4776e75543
# 30173    30173  PETCT_4776e75543
#
#                                                Study UID diagnosis condition  \
# 188    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 189    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 190    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 191    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 192    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# ...                                                  ...       ...       ...
# 30169  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 30170  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 30171  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 30172  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 30173  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 188         133          400
# 189         134          400
# 190         135          400
# 191         136          400
# 192         137          400
# ...         ...          ...
# 30169       327          400
# 30170       328          400
# 30171       329          400
# 30172       330          400
# 30173       331          400
#
#                                                imagePath  \
# 188    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 189    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 190    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 191    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 192    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30169  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 30170  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 30171  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 30172  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 30173  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width
# 188    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 189    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 190    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 191    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 192    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# ...                                                  ...     ...    ...
# 30169  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 30170  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 30171  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 30172  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 30173  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
#
# [3981 rows x 11 columns]

# %%
data_df[data_df.height <= 395]
# Out:
#        imageId        Subject ID  \
# 0            0  PETCT_f21755a99b
# 1            1  PETCT_f21755a99b
# 2            2  PETCT_f21755a99b
# 3            3  PETCT_f21755a99b
# 4            4  PETCT_f21755a99b
# ...        ...               ...
# 30740    30740  PETCT_3ba0277c0c
# 30741    30741  PETCT_3ba0277c0c
# 30742    30742  PETCT_3ba0277c0c
# 30743    30743  PETCT_3ba0277c0c
# 30744    30744  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis condition  \
# 0      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# ...                                                  ...       ...       ...
# 30740  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30741  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30742  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30743  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30744  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 0           157          400
# 1           158          400
# 2           159          400
# 3           160          400
# 4           161          400
# ...         ...          ...
# 30740       270          400
# 30741       271          400
# 30742       272          400
# 30743       273          400
# 30744       274          400
#
#                                                imagePath  \
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# ...                                                  ...     ...    ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
#
# [26764 rows x 11 columns]

# %%
data_df.boxplot(column=["height"])
plt.show()

# %%
data_df[data_df.height <= 395].boxplot(column=["height"])
plt.show()

# %%
data_df[data_df.height <= 395].height.max()
# Out:
# 368

# %%
data_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    11633
# LYMPHOMA        9783
# MELANOMA        9329
# Name: count, dtype: int64

# %%
# verify distribution of conditions with this filter applied
data_df[data_df.height <= 395].condition.value_counts()
# Out:
# condition
# LUNG_CANCER    11633
# LYMPHOMA        9396
# MELANOMA        5735
# Name: count, dtype: int64

# %% [markdown]
# The filter applied right above shows that most of the images with a discrepant height petrain to the MELANOMA condition.
#
# Since the final images will be resized to the 1024x1024 size and the image with highest height has 661px, all images will be maintained.

# %%
# keep original df and filter the data_df
# original_df = data_df.copy()
# data_df = data_df[data_df.height <= 395].copy()

# %% [markdown]
# # Split and Export Images

# %%
@dataclass(frozen=True)
class ImageResizeConfig:
    height: int = 368
    width: int = 400

# %%
def pre_process_and_export_record(row, is_segmentation=False):
    image_path = DatasetConfig.DATA_ROOT_TARGET + (row["segPath"] if is_segmentation else row["imagePath"])
    img = cv2.imread(image_path)
    # img = cv2.resize(img, (ImageResizeConfig.height, ImageResizeConfig.width))
    # image resize removed
    img = cv2.normalize(img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
    
    img_modality = "SEG" if is_segmentation else "PET"
    
    destination_path = f"{DatasetConfig.DATA_ROOT_TARGET}/{row.subset}/{img_modality}"
    pathlib.Path(destination_path).mkdir(parents=True, exist_ok=True)
    destination_path = f"{destination_path}/{row.imageId}.png"
    
    cv2.imwrite(destination_path,img)

# %%
data_df["subset"] = None

# %%
data_df.head()
# Out:
#    imageId        Subject ID  \
# 0        0  PETCT_f21755a99b
# 1        1  PETCT_f21755a99b
# 2        2  PETCT_f21755a99b
# 3        3  PETCT_f21755a99b
# 4        4  PETCT_f21755a99b
#
#                                            Study UID diagnosis condition  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
#
#    sliceNum  totalSlices                                          imagePath  \
# 0       157          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1       158          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2       159          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3       160          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4       161          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                              segPath  height  width subset
# 0  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 1  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 2  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 3  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 4  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None

# %%
data_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    11633
# LYMPHOMA        9783
# MELANOMA        9329
# Name: count, dtype: int64

# %%
data_df["Subject ID"].value_counts()
# Out:
# Subject ID
# PETCT_d8d9e52cd5    264
# PETCT_dc6174cb5d    250
# PETCT_1285b86bea    209
# PETCT_4c75fa4a5d    197
# PETCT_35c9c85a96    192
#                    ...
# PETCT_3ba0277c0c      5
# PETCT_41fadf6520      4
# PETCT_1f65acff65      4
# PETCT_0223010e46      3
# PETCT_5d994c3f44      2
# Name: count, Length: 489, dtype: int64

# %% [markdown]
# Both `condition` and `Subject ID` have to be taken into account when splitting the dataset.
#
# This dataset encompasses a total of 489 patients with 30.745 different images.

# %%
data_df[data_df.condition == "LUNG_CANCER"]["Subject ID"].value_counts().describe()
# Out:
# count    168.000000
# mean      69.244048
# std       35.365922
# min        6.000000
# 25%       41.750000
# 50%       64.000000
# 75%       90.250000
# max      172.000000
# Name: count, dtype: float64

# %%
data_df[data_df.condition == "LYMPHOMA"]["Subject ID"].value_counts().describe()
# Out:
# count    144.000000
# mean      67.937500
# std       41.851422
# min        3.000000
# 25%       34.000000
# 50%       62.000000
# 75%       93.250000
# max      180.000000
# Name: count, dtype: float64

# %%
data_df[data_df.condition == "MELANOMA"]["Subject ID"].value_counts().describe()
# Out:
# count    177.000000
# mean      52.706215
# std       50.048200
# min        2.000000
# 25%       15.000000
# 50%       39.000000
# 75%       68.000000
# max      264.000000
# Name: count, dtype: float64

# %% [markdown]
# Our rationale approach to split the dataset is to consider the proportion of each quartile. 80% of the patients within each quartile for image count per patient will be selected. Then, all the images pertaining to each patient will be considered into the respective subset (train or test).

# %%
data_df["Subject ID"].value_counts().reset_index(name='counts')
# Out:
#            Subject ID  counts
# 0    PETCT_d8d9e52cd5     264
# 1    PETCT_dc6174cb5d     250
# 2    PETCT_1285b86bea     209
# 3    PETCT_4c75fa4a5d     197
# 4    PETCT_35c9c85a96     192
# ..                ...     ...
# 484  PETCT_3ba0277c0c       5
# 485  PETCT_41fadf6520       4
# 486  PETCT_1f65acff65       4
# 487  PETCT_0223010e46       3
# 488  PETCT_5d994c3f44       2
#
# [489 rows x 2 columns]

# %%
def get_subject_id_list(sub_df):
    q1 = np.percentile(sub_df.counts, 25)
    q2 = np.percentile(sub_df.counts, 50)
    q3 = np.percentile(sub_df.counts, 75)
    
    print(q1, q2, q3)
    section_1 = sub_df[sub_df.counts < q1]
    section_2 = sub_df[(sub_df.counts >= q1) & (sub_df.counts < q2)]
    section_3 = sub_df[(sub_df.counts >= q2) & (sub_df.counts < q3)]
    section_4 = sub_df[sub_df.counts >= q3]
    
    selected_records = pd.concat([
        section_1.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
        section_2.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
        section_3.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
        section_4.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE)
    ])

    train_records = selected_records["Subject ID"].to_list()
    test_records = sub_df.drop(selected_records.index, inplace=False)["Subject ID"].to_list()
    print(f"{len(train_records)}/{len(test_records)}")
    
    return train_records, test_records

# %%
train_melanoma, test_melanoma = get_subject_id_list(data_df[data_df.condition == "MELANOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 15.0 39.0 68.0
# 142/35

# %%
train_lymphoma, test_lymphoma = get_subject_id_list(data_df[data_df.condition == "LYMPHOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 34.0 62.0 93.25
# 115/29

# %%
train_lung, test_lung = get_subject_id_list(data_df[data_df.condition == "LUNG_CANCER"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 41.75 64.0 90.25
# 135/33

# %%
train_subjects = [*train_melanoma, *train_lymphoma, *train_lung]
test_subjects = [*test_melanoma, *test_lymphoma, *test_lung]

# %%
print(len(train_subjects),len(test_subjects))
# Out:
# 392 97

# %%
train_df = data_df[data_df["Subject ID"].isin(train_subjects)].copy()
train_df.subset = "Train"
train_df
# Out:
#        imageId        Subject ID  \
# 188        188  PETCT_7ce196485f
# 189        189  PETCT_7ce196485f
# 190        190  PETCT_7ce196485f
# 191        191  PETCT_7ce196485f
# 192        192  PETCT_7ce196485f
# ...        ...               ...
# 30740    30740  PETCT_3ba0277c0c
# 30741    30741  PETCT_3ba0277c0c
# 30742    30742  PETCT_3ba0277c0c
# 30743    30743  PETCT_3ba0277c0c
# 30744    30744  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis condition  \
# 188    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 189    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 190    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 191    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 192    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# ...                                                  ...       ...       ...
# 30740  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30741  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30742  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30743  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30744  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 188         133          400
# 189         134          400
# 190         135          400
# 191         136          400
# 192         137          400
# ...         ...          ...
# 30740       270          400
# 30741       271          400
# 30742       272          400
# 30743       273          400
# 30744       274          400
#
#                                                imagePath  \
# 188    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 189    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 190    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 191    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 192    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 188    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 189    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 190    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 191    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 192    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# ...                                                  ...     ...    ...    ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
#
# [24231 rows x 12 columns]

# %%
test_df = data_df[data_df["Subject ID"].isin(test_subjects)].copy()
test_df.subset = "Test"
test_df
# Out:
#        imageId        Subject ID  \
# 0            0  PETCT_f21755a99b
# 1            1  PETCT_f21755a99b
# 2            2  PETCT_f21755a99b
# 3            3  PETCT_f21755a99b
# 4            4  PETCT_f21755a99b
# ...        ...               ...
# 30591    30591  PETCT_37472e737f
# 30592    30592  PETCT_37472e737f
# 30593    30593  PETCT_37472e737f
# 30594    30594  PETCT_37472e737f
# 30595    30595  PETCT_37472e737f
#
#                                                Study UID diagnosis  \
# 0      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE
# 1      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE
# 2      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE
# 3      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE
# 4      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE
# ...                                                  ...       ...
# 30591  1.3.6.1.4.1.14519.5.2.1.4219.6651.321569127236...  POSITIVE
# 30592  1.3.6.1.4.1.14519.5.2.1.4219.6651.321569127236...  POSITIVE
# 30593  1.3.6.1.4.1.14519.5.2.1.4219.6651.321569127236...  POSITIVE
# 30594  1.3.6.1.4.1.14519.5.2.1.4219.6651.321569127236...  POSITIVE
# 30595  1.3.6.1.4.1.14519.5.2.1.4219.6651.321569127236...  POSITIVE
#
#          condition  sliceNum  totalSlices  \
# 0         LYMPHOMA       157          400
# 1         LYMPHOMA       158          400
# 2         LYMPHOMA       159          400
# 3         LYMPHOMA       160          400
# 4         LYMPHOMA       161          400
# ...            ...       ...          ...
# 30591  LUNG_CANCER       236          400
# 30592  LUNG_CANCER       237          400
# 30593  LUNG_CANCER       238          400
# 30594  LUNG_CANCER       239          400
# 30595  LUNG_CANCER       240          400
#
#                                                imagePath  \
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30591  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...
# 30592  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...
# 30593  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...
# 30594  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...
# 30595  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# ...                                                  ...     ...    ...    ...
# 30591  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 30592  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 30593  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 30594  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 30595  /PETCT_37472e737f-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
#
# [6514 rows x 12 columns]

# %% [markdown]
# Extracting validation data from training samples:

# %%
train_melanoma, val_melanoma = get_subject_id_list(train_df[train_df.condition == "MELANOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
train_lymphoma, val_lymphoma = get_subject_id_list(train_df[train_df.condition == "LYMPHOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
train_lung, val_lung = get_subject_id_list(train_df[train_df.condition == "LUNG_CANCER"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 15.0 38.5 67.25
# 114/28
# 34.0 62.0 92.0
# 91/24
# 40.5 64.0 89.5
# 107/28

# %%
train_subjects = [*train_melanoma, *train_lymphoma, *train_lung]
val_subjects = [*val_melanoma, *val_lymphoma, *val_lung]

# %%
train_df = data_df[data_df["Subject ID"].isin(train_subjects)].copy()
train_df.subset = "Train"
train_df
# Out:
#        imageId        Subject ID  \
# 188        188  PETCT_7ce196485f
# 189        189  PETCT_7ce196485f
# 190        190  PETCT_7ce196485f
# 191        191  PETCT_7ce196485f
# 192        192  PETCT_7ce196485f
# ...        ...               ...
# 30740    30740  PETCT_3ba0277c0c
# 30741    30741  PETCT_3ba0277c0c
# 30742    30742  PETCT_3ba0277c0c
# 30743    30743  PETCT_3ba0277c0c
# 30744    30744  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis condition  \
# 188    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 189    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 190    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 191    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 192    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# ...                                                  ...       ...       ...
# 30740  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30741  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30742  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30743  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 30744  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 188         133          400
# 189         134          400
# 190         135          400
# 191         136          400
# 192         137          400
# ...         ...          ...
# 30740       270          400
# 30741       271          400
# 30742       272          400
# 30743       273          400
# 30744       274          400
#
#                                                imagePath  \
# 188    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 189    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 190    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 191    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 192    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 188    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 189    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 190    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 191    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# 192    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Train
# ...                                                  ...     ...    ...    ...
# 30740  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30741  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30742  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30743  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 30744  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
#
# [18639 rows x 12 columns]

# %%
val_df = data_df[data_df["Subject ID"].isin(val_subjects)].copy()
val_df.subset = "Valid"
val_df
# Out:
#        imageId        Subject ID  \
# 311        311  PETCT_61348439bf
# 312        312  PETCT_61348439bf
# 313        313  PETCT_61348439bf
# 314        314  PETCT_61348439bf
# 315        315  PETCT_61348439bf
# ...        ...               ...
# 30346    30346  PETCT_4a255db7bd
# 30347    30347  PETCT_4a255db7bd
# 30348    30348  PETCT_4a255db7bd
# 30349    30349  PETCT_4a255db7bd
# 30350    30350  PETCT_4a255db7bd
#
#                                                Study UID diagnosis condition  \
# 311    1.3.6.1.4.1.14519.5.2.1.4219.6651.225609493580...  POSITIVE  LYMPHOMA
# 312    1.3.6.1.4.1.14519.5.2.1.4219.6651.225609493580...  POSITIVE  LYMPHOMA
# 313    1.3.6.1.4.1.14519.5.2.1.4219.6651.225609493580...  POSITIVE  LYMPHOMA
# 314    1.3.6.1.4.1.14519.5.2.1.4219.6651.225609493580...  POSITIVE  LYMPHOMA
# 315    1.3.6.1.4.1.14519.5.2.1.4219.6651.225609493580...  POSITIVE  LYMPHOMA
# ...                                                  ...       ...       ...
# 30346  1.3.6.1.4.1.14519.5.2.1.4219.6651.272888327316...  POSITIVE  LYMPHOMA
# 30347  1.3.6.1.4.1.14519.5.2.1.4219.6651.272888327316...  POSITIVE  LYMPHOMA
# 30348  1.3.6.1.4.1.14519.5.2.1.4219.6651.272888327316...  POSITIVE  LYMPHOMA
# 30349  1.3.6.1.4.1.14519.5.2.1.4219.6651.272888327316...  POSITIVE  LYMPHOMA
# 30350  1.3.6.1.4.1.14519.5.2.1.4219.6651.272888327316...  POSITIVE  LYMPHOMA
#
#        sliceNum  totalSlices  \
# 311         156          400
# 312         157          400
# 313         158          400
# 314         159          400
# 315         160          400
# ...         ...          ...
# 30346       245          400
# 30347       246          400
# 30348       247          400
# 30349       248          400
# 30350       249          400
#
#                                                imagePath  \
# 311    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...
# 312    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...
# 313    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...
# 314    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...
# 315    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 30346  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...
# 30347  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...
# 30348  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...
# 30349  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...
# 30350  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 311    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...     332    400  Valid
# 312    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...     332    400  Valid
# 313    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...     332    400  Valid
# 314    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...     332    400  Valid
# 315    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...     332    400  Valid
# ...                                                  ...     ...    ...    ...
# 30346  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...     284    400  Valid
# 30347  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...     284    400  Valid
# 30348  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...     284    400  Valid
# 30349  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...     284    400  Valid
# 30350  /PETCT_4a255db7bd-1.3.6.1.4.1.14519.5.2.1.4219...     284    400  Valid
#
# [5592 rows x 12 columns]

# %% [markdown]
# Grouping subject slices count for each subsed in order to verify the result:

# %%
train_split_count = train_df["Subject ID"].value_counts().reset_index(name='counts')
train_split_count["subset"] = "Train"

val_split_count = val_df["Subject ID"].value_counts().reset_index(name='counts')
val_split_count["subset"] = "Valid"

test_split_count = test_df["Subject ID"].value_counts().reset_index(name='counts')
test_split_count["subset"] = "Test"

split_counts = pd.concat([train_split_count, val_split_count, test_split_count])

sns.boxplot(data=split_counts, x='subset', y='counts')
plt.show()

# %%
train_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    7123
# LYMPHOMA       5834
# MELANOMA       5682
# Name: count, dtype: int64

# %%
val_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    2129
# LYMPHOMA       1893
# MELANOMA       1570
# Name: count, dtype: int64

# %%
test_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    2381
# MELANOMA       2077
# LYMPHOMA       2056
# Name: count, dtype: int64

# %%
full_data = pd.concat([train_df, val_df, test_df]).sample(frac=1,random_state=DatasetConfig.SEED_VALUE)
full_data
# Out:
#        imageId        Subject ID  \
# 20534    20534  PETCT_d4b2ff9721
# 2034      2034  PETCT_b04be2846e
# 328        328  PETCT_61348439bf
# 607        607  PETCT_1285b86bea
# 17296    17296  PETCT_9a583160ea
# ...        ...               ...
# 14445    14445  PETCT_86153b2974
# 8622      8622  PETCT_27d69a8466
# 18878    18878  PETCT_61663450f8
# 1782      1782  PETCT_a4ff5d0d9d
# 3346      3346  PETCT_4404466919
#
#                                                Study UID diagnosis  \
# 20534  1.3.6.1.4.1.14519.5.2.1.4219.6651.208751808367...  POSITIVE
# 2034   1.3.6.1.4.1.14519.5.2.1.4219.6651.363928780936...  POSITIVE
# 328    1.3.6.1.4.1.14519.5.2.1.4219.6651.225609493580...  POSITIVE
# 607    1.3.6.1.4.1.14519.5.2.1.4219.6651.282505005604...  POSITIVE
# 17296  1.3.6.1.4.1.14519.5.2.1.4219.6651.110285419036...  POSITIVE
# ...                                                  ...       ...
# 14445  1.3.6.1.4.1.14519.5.2.1.4219.6651.131129104566...  POSITIVE
# 8622   1.3.6.1.4.1.14519.5.2.1.4219.6651.284059862038...  POSITIVE
# 18878  1.3.6.1.4.1.14519.5.2.1.4219.6651.233020264231...  POSITIVE
# 1782   1.3.6.1.4.1.14519.5.2.1.4219.6651.221723698336...  POSITIVE
# 3346   1.3.6.1.4.1.14519.5.2.1.4219.6651.249163476670...  POSITIVE
#
#          condition  sliceNum  totalSlices  \
# 20534  LUNG_CANCER       259          400
# 2034      LYMPHOMA       176          400
# 328       LYMPHOMA       174          400
# 607       MELANOMA       120          400
# 17296     MELANOMA       222          400
# ...            ...       ...          ...
# 14445     MELANOMA       252          400
# 8622   LUNG_CANCER       210          400
# 18878     MELANOMA       239          400
# 1782      LYMPHOMA       238          400
# 3346      MELANOMA       241          400
#
#                                                imagePath  \
# 20534  /PETCT_d4b2ff9721-1.3.6.1.4.1.14519.5.2.1.4219...
# 2034   /PETCT_b04be2846e-1.3.6.1.4.1.14519.5.2.1.4219...
# 328    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...
# 607    /PETCT_1285b86bea-1.3.6.1.4.1.14519.5.2.1.4219...
# 17296  /PETCT_9a583160ea-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 14445  /PETCT_86153b2974-1.3.6.1.4.1.14519.5.2.1.4219...
# 8622   /PETCT_27d69a8466-1.3.6.1.4.1.14519.5.2.1.4219...
# 18878  /PETCT_61663450f8-1.3.6.1.4.1.14519.5.2.1.4219...
# 1782   /PETCT_a4ff5d0d9d-1.3.6.1.4.1.14519.5.2.1.4219...
# 3346   /PETCT_4404466919-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 20534  /PETCT_d4b2ff9721-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 2034   /PETCT_b04be2846e-1.3.6.1.4.1.14519.5.2.1.4219...     326    400   Test
# 328    /PETCT_61348439bf-1.3.6.1.4.1.14519.5.2.1.4219...     332    400  Valid
# 607    /PETCT_1285b86bea-1.3.6.1.4.1.14519.5.2.1.4219...     300    400  Valid
# 17296  /PETCT_9a583160ea-1.3.6.1.4.1.14519.5.2.1.4219...     335    400  Train
# ...                                                  ...     ...    ...    ...
# 14445  /PETCT_86153b2974-1.3.6.1.4.1.14519.5.2.1.4219...     368    400  Valid
# 8622   /PETCT_27d69a8466-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Valid
# 18878  /PETCT_61663450f8-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 1782   /PETCT_a4ff5d0d9d-1.3.6.1.4.1.14519.5.2.1.4219...     536    400  Train
# 3346   /PETCT_4404466919-1.3.6.1.4.1.14519.5.2.1.4219...     636    400  Train
#
# [30745 rows x 12 columns]

# %%
full_data.subset.value_counts()
# Out:
# subset
# Train    18639
# Test      6514
# Valid     5592
# Name: count, dtype: int64

# %%
# validating if both dataframes (initial and resulting) have the same size
len(data_df) == len(full_data)
# Out:
# True

# %%
from tqdm import tqdm

# %%
for index, row in tqdm(full_data.iterrows(), total=len(full_data)):
    pre_process_and_export_record(row)
    pre_process_and_export_record(row, True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 30745/30745 [01:50<00:00, 277.56it/s]
