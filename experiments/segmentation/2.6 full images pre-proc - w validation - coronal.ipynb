# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from dataclasses import dataclass
import pathlib

# %%
@dataclass(frozen=True)
class DatasetConfig:
    SEED_VALUE:  int = 41
    CUT_PLANE:   str = "coronal"
         
    DATA_ROOT_SOURCE_PATH: str = '/home/jovyan/data/auto-pet-iii/2024-05-10_Autopet_v1.1'
    MAIN_DATA_CSV_PATH: str = DATA_ROOT_SOURCE_PATH + '/fdg_metadata.csv'
    DATA_ROOT_TARGET:  str = f'/home/jovyan/data/segmentation/autopet-full-{CUT_PLANE}' 
    DATA_ROOT_TRAIN:  str = DATA_ROOT_TARGET + '/Train' 
    DATA_ROOT_VALID:  str = DATA_ROOT_TARGET + '/Valid'
    DATA_ROOT_TEST:   str = DATA_ROOT_TARGET + '/Test'
    DATA_TEST_GT:     str = DATA_ROOT_TARGET + '/Test.csv'

# %%
# train, val and test split

# %%
data_df = pd.read_csv(DatasetConfig.DATA_ROOT_TARGET + "/data_description.csv")
data_df
# Out:
#        Unnamed: 0        Subject ID  \
# 0               0  PETCT_f21755a99b
# 1               1  PETCT_f21755a99b
# 2               2  PETCT_f21755a99b
# 3               3  PETCT_f21755a99b
# 4               4  PETCT_f21755a99b
# ...           ...               ...
# 25965       25965  PETCT_3ba0277c0c
# 25966       25966  PETCT_3ba0277c0c
# 25967       25967  PETCT_3ba0277c0c
# 25968       25968  PETCT_3ba0277c0c
# 25969       25969  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis condition  \
# 0      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# ...                                                  ...       ...       ...
# 25965  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25966  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25967  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25968  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25969  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 0           157          400
# 1           158          400
# 2           159          400
# 3           160          400
# 4           161          400
# ...         ...          ...
# 25965       211          400
# 25966       212          400
# 25967       213          400
# 25968       214          400
# 25969       215          400
#
#                                                imagePath  \
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# ...                                                  ...     ...    ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
#
# [25970 rows x 11 columns]

# %%
data_df.diagnosis.value_counts()
# Out:
# diagnosis
# POSITIVE    25970
# Name: count, dtype: int64

# %%
col_names = data_df.columns.to_list()
col_names[0] = "imageId"
col_names
# Out:
# ['imageId',
#  'Subject ID',
#  'Study UID',
#  'diagnosis',
#  'condition',
#  'sliceNum',
#  'totalSlices',
#  'imagePath',
#  'segPath',
#  'height',
#  'width']

# %%
data_df.columns = col_names
data_df.head()
# Out:
#    imageId        Subject ID  \
# 0        0  PETCT_f21755a99b
# 1        1  PETCT_f21755a99b
# 2        2  PETCT_f21755a99b
# 3        3  PETCT_f21755a99b
# 4        4  PETCT_f21755a99b
#
#                                            Study UID diagnosis condition  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
#
#    sliceNum  totalSlices                                          imagePath  \
# 0       157          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1       158          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2       159          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3       160          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4       161          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                              segPath  height  width
# 0  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 1  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 2  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 3  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 4  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400

# %%
# new height will be based on the mean value
data_df.height.describe()
# Out:
# count    25970.000000
# mean       346.512630
# std         95.206246
# min        242.000000
# 25%        284.000000
# 50%        326.000000
# 75%        326.000000
# max        661.000000
# Name: height, dtype: float64

# %%
data_df[data_df.height > 395]
# Out:
#        imageId        Subject ID  \
# 149        149  PETCT_7ce196485f
# 150        150  PETCT_7ce196485f
# 151        151  PETCT_7ce196485f
# 152        152  PETCT_7ce196485f
# 153        153  PETCT_7ce196485f
# ...        ...               ...
# 25547    25547  PETCT_4776e75543
# 25548    25548  PETCT_4776e75543
# 25549    25549  PETCT_4776e75543
# 25550    25550  PETCT_4776e75543
# 25551    25551  PETCT_4776e75543
#
#                                                Study UID diagnosis condition  \
# 149    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 150    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 151    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 152    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 153    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# ...                                                  ...       ...       ...
# 25547  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 25548  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 25549  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 25550  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
# 25551  1.3.6.1.4.1.14519.5.2.1.4219.6651.323483836183...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 149         177          400
# 150         178          400
# 151         179          400
# 152         180          400
# 153         181          400
# ...         ...          ...
# 25547       207          400
# 25548       208          400
# 25549       209          400
# 25550       210          400
# 25551       211          400
#
#                                                imagePath  \
# 149    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 150    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 151    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 152    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 153    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25547  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 25548  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 25549  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 25550  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
# 25551  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width
# 149    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 150    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 151    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 152    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# 153    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400
# ...                                                  ...     ...    ...
# 25547  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 25548  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 25549  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 25550  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
# 25551  /PETCT_4776e75543-1.3.6.1.4.1.14519.5.2.1.4219...     649    400
#
# [3680 rows x 11 columns]

# %%
data_df[data_df.height <= 395]
# Out:
#        imageId        Subject ID  \
# 0            0  PETCT_f21755a99b
# 1            1  PETCT_f21755a99b
# 2            2  PETCT_f21755a99b
# 3            3  PETCT_f21755a99b
# 4            4  PETCT_f21755a99b
# ...        ...               ...
# 25965    25965  PETCT_3ba0277c0c
# 25966    25966  PETCT_3ba0277c0c
# 25967    25967  PETCT_3ba0277c0c
# 25968    25968  PETCT_3ba0277c0c
# 25969    25969  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis condition  \
# 0      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# ...                                                  ...       ...       ...
# 25965  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25966  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25967  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25968  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
# 25969  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 0           157          400
# 1           158          400
# 2           159          400
# 3           160          400
# 4           161          400
# ...         ...          ...
# 25965       211          400
# 25966       212          400
# 25967       213          400
# 25968       214          400
# 25969       215          400
#
#                                                imagePath  \
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400
# ...                                                  ...     ...    ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400
#
# [22290 rows x 11 columns]

# %%
data_df.boxplot(column=["height"])
plt.show()

# %%
data_df[data_df.height <= 395].boxplot(column=["height"])
plt.show()

# %%
data_df[data_df.height <= 395].height.max()
# Out:
# 368

# %%
data_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    10281
# MELANOMA        8407
# LYMPHOMA        7282
# Name: count, dtype: int64

# %%
# verify distribution of conditions with this filter applied
data_df[data_df.height <= 395].condition.value_counts()
# Out:
# condition
# LUNG_CANCER    10281
# LYMPHOMA        6933
# MELANOMA        5076
# Name: count, dtype: int64

# %% [markdown]
# The filter applied right above shows that most of the images with a discrepant height petrain to the MELANOMA condition.
#
# Since the final images will be resized to the 1024x1024 size and the image with highest height has 661px, all images will be maintained.

# %%
# keep original df and filter the data_df
# original_df = data_df.copy()
# data_df = data_df[data_df.height <= 395].copy()

# %% [markdown]
# # Split and Export Images

# %%
@dataclass(frozen=True)
class ImageResizeConfig:
    height: int = 368
    width: int = 400

# %%
def pre_process_and_export_record(row, is_segmentation=False):
    image_path = DatasetConfig.DATA_ROOT_TARGET + (row["segPath"] if is_segmentation else row["imagePath"])
    img = cv2.imread(image_path)
    # img = cv2.resize(img, (ImageResizeConfig.height, ImageResizeConfig.width))
    # image resize removed
    img = cv2.normalize(img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
    
    img_modality = "SEG" if is_segmentation else "PET"
    
    destination_path = f"{DatasetConfig.DATA_ROOT_TARGET}/{row.subset}/{img_modality}"
    pathlib.Path(destination_path).mkdir(parents=True, exist_ok=True)
    destination_path = f"{destination_path}/{row.imageId}.png"
    
    cv2.imwrite(destination_path,img)

# %%
data_df["subset"] = None

# %%
data_df.head()
# Out:
#    imageId        Subject ID  \
# 0        0  PETCT_f21755a99b
# 1        1  PETCT_f21755a99b
# 2        2  PETCT_f21755a99b
# 3        3  PETCT_f21755a99b
# 4        4  PETCT_f21755a99b
#
#                                            Study UID diagnosis condition  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
#
#    sliceNum  totalSlices                                          imagePath  \
# 0       157          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1       158          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2       159          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3       160          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4       161          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                              segPath  height  width subset
# 0  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 1  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 2  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 3  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None
# 4  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   None

# %%
data_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    10281
# MELANOMA        8407
# LYMPHOMA        7282
# Name: count, dtype: int64

# %%
data_df["Subject ID"].value_counts()
# Out:
# Subject ID
# PETCT_d8d9e52cd5    244
# PETCT_dc6174cb5d    192
# PETCT_1285b86bea    175
# PETCT_4c75fa4a5d    142
# PETCT_73597f33fe    139
#                    ...
# PETCT_2a6f4f0753      5
# PETCT_55ae7986e1      5
# PETCT_3ba0277c0c      5
# PETCT_0223010e46      4
# PETCT_5d994c3f44      4
# Name: count, Length: 489, dtype: int64

# %% [markdown]
# Both `condition` and `Subject ID` have to be taken into account when splitting the dataset.
#
# This dataset encompasses a total of 489 patients with 30.745 different images.

# %%
data_df[data_df.condition == "LUNG_CANCER"]["Subject ID"].value_counts().describe()
# Out:
# count    168.000000
# mean      61.196429
# std       25.615597
# min        5.000000
# 25%       42.750000
# 50%       59.000000
# 75%       76.250000
# max      135.000000
# Name: count, dtype: float64

# %%
data_df[data_df.condition == "LYMPHOMA"]["Subject ID"].value_counts().describe()
# Out:
# count    144.000000
# mean      50.569444
# std       25.215894
# min        4.000000
# 25%       32.750000
# 50%       49.000000
# 75%       65.000000
# max      132.000000
# Name: count, dtype: float64

# %%
data_df[data_df.condition == "MELANOMA"]["Subject ID"].value_counts().describe()
# Out:
# count    177.000000
# mean      47.497175
# std       38.629229
# min        4.000000
# 25%       18.000000
# 50%       40.000000
# 75%       66.000000
# max      244.000000
# Name: count, dtype: float64

# %% [markdown]
# Our rationale approach to split the dataset is to consider the proportion of each quartile. 80% of the patients within each quartile for image count per patient will be selected. Then, all the images pertaining to each patient will be considered into the respective subset (train or test).

# %%
data_df["Subject ID"].value_counts().reset_index(name='counts')
# Out:
#            Subject ID  counts
# 0    PETCT_d8d9e52cd5     244
# 1    PETCT_dc6174cb5d     192
# 2    PETCT_1285b86bea     175
# 3    PETCT_4c75fa4a5d     142
# 4    PETCT_73597f33fe     139
# ..                ...     ...
# 484  PETCT_2a6f4f0753       5
# 485  PETCT_55ae7986e1       5
# 486  PETCT_3ba0277c0c       5
# 487  PETCT_0223010e46       4
# 488  PETCT_5d994c3f44       4
#
# [489 rows x 2 columns]

# %%
def get_subject_id_list(sub_df):
    q1 = np.percentile(sub_df.counts, 25)
    q2 = np.percentile(sub_df.counts, 50)
    q3 = np.percentile(sub_df.counts, 75)
    
    print(q1, q2, q3)
    section_1 = sub_df[sub_df.counts < q1]
    section_2 = sub_df[(sub_df.counts >= q1) & (sub_df.counts < q2)]
    section_3 = sub_df[(sub_df.counts >= q2) & (sub_df.counts < q3)]
    section_4 = sub_df[sub_df.counts >= q3]
    
    selected_records = pd.concat([
        section_1.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
        section_2.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
        section_3.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
        section_4.sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE)
    ])

    train_records = selected_records["Subject ID"].to_list()
    test_records = sub_df.drop(selected_records.index, inplace=False)["Subject ID"].to_list()
    print(f"{len(train_records)}/{len(test_records)}")
    
    return train_records, test_records

# %%
train_melanoma, test_melanoma = get_subject_id_list(data_df[data_df.condition == "MELANOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 18.0 40.0 66.0
# 143/34

# %%
train_lymphoma, test_lymphoma = get_subject_id_list(data_df[data_df.condition == "LYMPHOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 32.75 49.0 65.0
# 115/29

# %%
train_lung, test_lung = get_subject_id_list(data_df[data_df.condition == "LUNG_CANCER"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 42.75 59.0 76.25
# 135/33

# %%
train_subjects = [*train_melanoma, *train_lymphoma, *train_lung]
test_subjects = [*test_melanoma, *test_lymphoma, *test_lung]

# %%
print(len(train_subjects),len(test_subjects))
# Out:
# 393 96

# %%
train_df = data_df[data_df["Subject ID"].isin(train_subjects)].copy()
train_df.subset = "Train"
train_df
# Out:
#        imageId        Subject ID  \
# 63          63  PETCT_605369e88d
# 64          64  PETCT_605369e88d
# 65          65  PETCT_605369e88d
# 66          66  PETCT_605369e88d
# 67          67  PETCT_605369e88d
# ...        ...               ...
# 25965    25965  PETCT_3ba0277c0c
# 25966    25966  PETCT_3ba0277c0c
# 25967    25967  PETCT_3ba0277c0c
# 25968    25968  PETCT_3ba0277c0c
# 25969    25969  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis  \
# 63     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 64     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 65     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 66     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 67     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# ...                                                  ...       ...
# 25965  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25966  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25967  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25968  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25969  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
#
#          condition  sliceNum  totalSlices  \
# 63     LUNG_CANCER       165          400
# 64     LUNG_CANCER       166          400
# 65     LUNG_CANCER       167          400
# 66     LUNG_CANCER       168          400
# 67     LUNG_CANCER       169          400
# ...            ...       ...          ...
# 25965     MELANOMA       211          400
# 25966     MELANOMA       212          400
# 25967     MELANOMA       213          400
# 25968     MELANOMA       214          400
# 25969     MELANOMA       215          400
#
#                                                imagePath  \
# 63     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 64     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 65     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 66     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 67     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 63     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 64     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 65     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 66     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 67     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# ...                                                  ...     ...    ...    ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
#
# [20492 rows x 12 columns]

# %%
test_df = data_df[data_df["Subject ID"].isin(test_subjects)].copy()
test_df.subset = "Test"
test_df
# Out:
#        imageId        Subject ID  \
# 0            0  PETCT_f21755a99b
# 1            1  PETCT_f21755a99b
# 2            2  PETCT_f21755a99b
# 3            3  PETCT_f21755a99b
# 4            4  PETCT_f21755a99b
# ...        ...               ...
# 25916    25916  PETCT_aa27cb9156
# 25917    25917  PETCT_aa27cb9156
# 25918    25918  PETCT_aa27cb9156
# 25919    25919  PETCT_aa27cb9156
# 25920    25920  PETCT_aa27cb9156
#
#                                                Study UID diagnosis condition  \
# 0      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 1      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 2      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 3      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# 4      1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE  LYMPHOMA
# ...                                                  ...       ...       ...
# 25916  1.3.6.1.4.1.14519.5.2.1.4219.6651.296549326544...  POSITIVE  LYMPHOMA
# 25917  1.3.6.1.4.1.14519.5.2.1.4219.6651.296549326544...  POSITIVE  LYMPHOMA
# 25918  1.3.6.1.4.1.14519.5.2.1.4219.6651.296549326544...  POSITIVE  LYMPHOMA
# 25919  1.3.6.1.4.1.14519.5.2.1.4219.6651.296549326544...  POSITIVE  LYMPHOMA
# 25920  1.3.6.1.4.1.14519.5.2.1.4219.6651.296549326544...  POSITIVE  LYMPHOMA
#
#        sliceNum  totalSlices  \
# 0           157          400
# 1           158          400
# 2           159          400
# 3           160          400
# 4           161          400
# ...         ...          ...
# 25916       218          400
# 25917       219          400
# 25918       220          400
# 25919       221          400
# 25920       222          400
#
#                                                imagePath  \
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25916  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...
# 25917  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...
# 25918  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...
# 25919  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...
# 25920  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 0      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 1      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 2      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 3      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 4      /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# ...                                                  ...     ...    ...    ...
# 25916  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 25917  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 25918  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 25919  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 25920  /PETCT_aa27cb9156-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
#
# [5478 rows x 12 columns]

# %% [markdown]
# Extracting validation data from training samples:

# %%
train_melanoma, val_melanoma = get_subject_id_list(train_df[train_df.condition == "MELANOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
train_lymphoma, val_lymphoma = get_subject_id_list(train_df[train_df.condition == "LYMPHOMA"]["Subject ID"].value_counts().reset_index(name='counts'))
train_lung, val_lung = get_subject_id_list(train_df[train_df.condition == "LUNG_CANCER"]["Subject ID"].value_counts().reset_index(name='counts'))
# Out:
# 18.0 40.0 66.0
# 114/29
# 32.5 49.0 65.0
# 92/23
# 42.5 59.0 75.5
# 107/28

# %%
train_subjects = [*train_melanoma, *train_lymphoma, *train_lung]
val_subjects = [*val_melanoma, *val_lymphoma, *val_lung]

# %%
train_df = data_df[data_df["Subject ID"].isin(train_subjects)].copy()
train_df.subset = "Train"
train_df
# Out:
#        imageId        Subject ID  \
# 63          63  PETCT_605369e88d
# 64          64  PETCT_605369e88d
# 65          65  PETCT_605369e88d
# 66          66  PETCT_605369e88d
# 67          67  PETCT_605369e88d
# ...        ...               ...
# 25965    25965  PETCT_3ba0277c0c
# 25966    25966  PETCT_3ba0277c0c
# 25967    25967  PETCT_3ba0277c0c
# 25968    25968  PETCT_3ba0277c0c
# 25969    25969  PETCT_3ba0277c0c
#
#                                                Study UID diagnosis  \
# 63     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 64     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 65     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 66     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# 67     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE
# ...                                                  ...       ...
# 25965  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25966  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25967  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25968  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
# 25969  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE
#
#          condition  sliceNum  totalSlices  \
# 63     LUNG_CANCER       165          400
# 64     LUNG_CANCER       166          400
# 65     LUNG_CANCER       167          400
# 66     LUNG_CANCER       168          400
# 67     LUNG_CANCER       169          400
# ...            ...       ...          ...
# 25965     MELANOMA       211          400
# 25966     MELANOMA       212          400
# 25967     MELANOMA       213          400
# 25968     MELANOMA       214          400
# 25969     MELANOMA       215          400
#
#                                                imagePath  \
# 63     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 64     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 65     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 66     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# 67     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 63     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 64     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 65     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 66     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 67     /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# ...                                                  ...     ...    ...    ...
# 25965  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25966  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25967  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25968  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
# 25969  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308    400  Train
#
# [15869 rows x 12 columns]

# %%
val_df = data_df[data_df["Subject ID"].isin(val_subjects)].copy()
val_df.subset = "Valid"
val_df
# Out:
#        imageId        Subject ID  \
# 149        149  PETCT_7ce196485f
# 150        150  PETCT_7ce196485f
# 151        151  PETCT_7ce196485f
# 152        152  PETCT_7ce196485f
# 153        153  PETCT_7ce196485f
# ...        ...               ...
# 25679    25679  PETCT_1019ae8551
# 25680    25680  PETCT_1019ae8551
# 25681    25681  PETCT_1019ae8551
# 25682    25682  PETCT_1019ae8551
# 25683    25683  PETCT_1019ae8551
#
#                                                Study UID diagnosis condition  \
# 149    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 150    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 151    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 152    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# 153    1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE  MELANOMA
# ...                                                  ...       ...       ...
# 25679  1.3.6.1.4.1.14519.5.2.1.4219.6651.249572262389...  POSITIVE  MELANOMA
# 25680  1.3.6.1.4.1.14519.5.2.1.4219.6651.249572262389...  POSITIVE  MELANOMA
# 25681  1.3.6.1.4.1.14519.5.2.1.4219.6651.249572262389...  POSITIVE  MELANOMA
# 25682  1.3.6.1.4.1.14519.5.2.1.4219.6651.249572262389...  POSITIVE  MELANOMA
# 25683  1.3.6.1.4.1.14519.5.2.1.4219.6651.249572262389...  POSITIVE  MELANOMA
#
#        sliceNum  totalSlices  \
# 149         177          400
# 150         178          400
# 151         179          400
# 152         180          400
# 153         181          400
# ...         ...          ...
# 25679       205          400
# 25680       206          400
# 25681       207          400
# 25682       208          400
# 25683       209          400
#
#                                                imagePath  \
# 149    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 150    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 151    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 152    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# 153    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 25679  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...
# 25680  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...
# 25681  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...
# 25682  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...
# 25683  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 149    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Valid
# 150    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Valid
# 151    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Valid
# 152    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Valid
# 153    /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558    400  Valid
# ...                                                  ...     ...    ...    ...
# 25679  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...     338    400  Valid
# 25680  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...     338    400  Valid
# 25681  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...     338    400  Valid
# 25682  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...     338    400  Valid
# 25683  /PETCT_1019ae8551-1.3.6.1.4.1.14519.5.2.1.4219...     338    400  Valid
#
# [4623 rows x 12 columns]

# %% [markdown]
# Grouping subject slices count for each subsed in order to verify the result:

# %%
train_split_count = train_df["Subject ID"].value_counts().reset_index(name='counts')
train_split_count["subset"] = "Train"

val_split_count = val_df["Subject ID"].value_counts().reset_index(name='counts')
val_split_count["subset"] = "Valid"

test_split_count = test_df["Subject ID"].value_counts().reset_index(name='counts')
test_split_count["subset"] = "Test"

split_counts = pd.concat([train_split_count, val_split_count, test_split_count])

sns.boxplot(data=split_counts, x='subset', y='counts')
plt.show()

# %%
train_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    6346
# MELANOMA       5117
# LYMPHOMA       4406
# Name: count, dtype: int64

# %%
val_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    1845
# MELANOMA       1475
# LYMPHOMA       1303
# Name: count, dtype: int64

# %%
test_df.condition.value_counts()
# Out:
# condition
# LUNG_CANCER    2090
# MELANOMA       1815
# LYMPHOMA       1573
# Name: count, dtype: int64

# %%
full_data = pd.concat([train_df, val_df, test_df]).sample(frac=1,random_state=DatasetConfig.SEED_VALUE)
full_data
# Out:
#        imageId        Subject ID  \
# 23734    23734  PETCT_bc80d06f97
# 19019    19019  PETCT_a4cd2b10de
# 6985      6985  PETCT_d31c9ebd93
# 13476    13476  PETCT_13b40a817b
# 24024    24024  PETCT_0168f65af8
# ...        ...               ...
# 14347    14347  PETCT_9a583160ea
# 3713      3713  PETCT_0e2034240b
# 25328    25328  PETCT_9c9a347388
# 1891      1891  PETCT_c2a51a65c6
# 3830      3830  PETCT_8b74860ce6
#
#                                                Study UID diagnosis  \
# 23734  1.3.6.1.4.1.14519.5.2.1.4219.6651.176679212615...  POSITIVE
# 19019  1.3.6.1.4.1.14519.5.2.1.4219.6651.162317265485...  POSITIVE
# 6985   1.3.6.1.4.1.14519.5.2.1.4219.6651.179056722297...  POSITIVE
# 13476  1.3.6.1.4.1.14519.5.2.1.4219.6651.218254795709...  POSITIVE
# 24024  1.3.6.1.4.1.14519.5.2.1.4219.6651.304086288813...  POSITIVE
# ...                                                  ...       ...
# 14347  1.3.6.1.4.1.14519.5.2.1.4219.6651.110285419036...  POSITIVE
# 3713   1.3.6.1.4.1.14519.5.2.1.4219.6651.121095238781...  POSITIVE
# 25328  1.3.6.1.4.1.14519.5.2.1.4219.6651.877463610141...  POSITIVE
# 1891   1.3.6.1.4.1.14519.5.2.1.4219.6651.338164776458...  POSITIVE
# 3830   1.3.6.1.4.1.14519.5.2.1.4219.6651.205289083224...  POSITIVE
#
#          condition  sliceNum  totalSlices  \
# 23734     MELANOMA       178          400
# 19019     MELANOMA       207          400
# 6985      LYMPHOMA       223          400
# 13476  LUNG_CANCER       184          400
# 24024  LUNG_CANCER       172          400
# ...            ...       ...          ...
# 14347     MELANOMA       155          400
# 3713   LUNG_CANCER       183          400
# 25328  LUNG_CANCER       206          400
# 1891   LUNG_CANCER       200          400
# 3830      LYMPHOMA       231          400
#
#                                                imagePath  \
# 23734  /PETCT_bc80d06f97-1.3.6.1.4.1.14519.5.2.1.4219...
# 19019  /PETCT_a4cd2b10de-1.3.6.1.4.1.14519.5.2.1.4219...
# 6985   /PETCT_d31c9ebd93-1.3.6.1.4.1.14519.5.2.1.4219...
# 13476  /PETCT_13b40a817b-1.3.6.1.4.1.14519.5.2.1.4219...
# 24024  /PETCT_0168f65af8-1.3.6.1.4.1.14519.5.2.1.4219...
# ...                                                  ...
# 14347  /PETCT_9a583160ea-1.3.6.1.4.1.14519.5.2.1.4219...
# 3713   /PETCT_0e2034240b-1.3.6.1.4.1.14519.5.2.1.4219...
# 25328  /PETCT_9c9a347388-1.3.6.1.4.1.14519.5.2.1.4219...
# 1891   /PETCT_c2a51a65c6-1.3.6.1.4.1.14519.5.2.1.4219...
# 3830   /PETCT_8b74860ce6-1.3.6.1.4.1.14519.5.2.1.4219...
#
#                                                  segPath  height  width subset
# 23734  /PETCT_bc80d06f97-1.3.6.1.4.1.14519.5.2.1.4219...     577    400  Train
# 19019  /PETCT_a4cd2b10de-1.3.6.1.4.1.14519.5.2.1.4219...     368    400  Train
# 6985   /PETCT_d31c9ebd93-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 13476  /PETCT_13b40a817b-1.3.6.1.4.1.14519.5.2.1.4219...     326    400   Test
# 24024  /PETCT_0168f65af8-1.3.6.1.4.1.14519.5.2.1.4219...     326    400   Test
# ...                                                  ...     ...    ...    ...
# 14347  /PETCT_9a583160ea-1.3.6.1.4.1.14519.5.2.1.4219...     335    400  Train
# 3713   /PETCT_0e2034240b-1.3.6.1.4.1.14519.5.2.1.4219...     284    400   Test
# 25328  /PETCT_9c9a347388-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Valid
# 1891   /PETCT_c2a51a65c6-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
# 3830   /PETCT_8b74860ce6-1.3.6.1.4.1.14519.5.2.1.4219...     326    400  Train
#
# [25970 rows x 12 columns]

# %%
full_data.subset.value_counts()
# Out:
# subset
# Train    15869
# Test      5478
# Valid     4623
# Name: count, dtype: int64

# %%
# validating if both dataframes (initial and resulting) have the same size
len(data_df) == len(full_data)
# Out:
# True

# %%
from tqdm import tqdm

# %%
for index, row in tqdm(full_data.iterrows(), total=len(full_data)):
    pre_process_and_export_record(row)
    pre_process_and_export_record(row, True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 25970/25970 [01:40<00:00, 259.38it/s]
