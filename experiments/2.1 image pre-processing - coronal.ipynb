# %%
import pandas as pd
import numpy as np
import cv2
from dataclasses import dataclass
import pathlib

# %%
@dataclass(frozen=True)
class DatasetConfig:
    SEED_VALUE:  int = 41
    CUT_PLANE:   str = "coronal"
         
    DATA_ROOT_SOURCE_PATH: str = '/home/jovyan/data/auto-pet-iii/2024-05-10_Autopet_v1.1'
    MAIN_DATA_CSV_PATH: str = DATA_ROOT_SOURCE_PATH + '/fdg_metadata.csv'
    DATA_ROOT_TARGET:  str = f'/home/jovyan/data/pre-processed-autopet-min-{CUT_PLANE}' 
    DATA_ROOT_TRAIN:  str = DATA_ROOT_TARGET + '/Train' 
    DATA_ROOT_VALID:  str = DATA_ROOT_TARGET + '/Valid'
    DATA_ROOT_TEST:   str = DATA_ROOT_TARGET + '/Test'
    DATA_TEST_GT:     str = DATA_ROOT_TARGET + '/Test.csv'

# %%
# train, val and test split

# %%
data_df = pd.read_csv(DatasetConfig.DATA_ROOT_TARGET + "/data_description.csv")
data_df
# Out:
#       Unnamed: 0        Subject ID  \
# 0              0  PETCT_f21755a99b
# 1              1  PETCT_176bdc5388
# 2              2  PETCT_605369e88d
# 3              3  PETCT_846c1af245
# 4              4  PETCT_7ce196485f
# ...          ...               ...
# 997          997  PETCT_193dea6ac7
# 998          998  PETCT_80ccbdadf9
# 999          999  PETCT_3bce0eb7aa
# 1000        1000  PETCT_3ba0277c0c
# 1001        1001  PETCT_48a34ccdf0
#
#                                               Study UID diagnosis  sliceNum  \
# 0     1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE       196
# 1     1.3.6.1.4.1.14519.5.2.1.4219.6651.908703633623...  NEGATIVE       196
# 2     1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE       207
# 3     1.3.6.1.4.1.14519.5.2.1.4219.6651.158562682786...  NEGATIVE       207
# 4     1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE       215
# ...                                                 ...       ...       ...
# 997   1.3.6.1.4.1.14519.5.2.1.4219.6651.224241512383...  NEGATIVE       191
# 998   1.3.6.1.4.1.14519.5.2.1.4219.6651.478619815683...  POSITIVE       181
# 999   1.3.6.1.4.1.14519.5.2.1.4219.6651.222796109751...  NEGATIVE       181
# 1000  1.3.6.1.4.1.14519.5.2.1.4219.6651.146051428537...  POSITIVE       212
# 1001  1.3.6.1.4.1.14519.5.2.1.4219.6651.232291314290...  NEGATIVE       212
#
#       totalSlices                                           filePath  height  \
# 0             400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 1             400  /PETCT_176bdc5388-1.3.6.1.4.1.14519.5.2.1.4219...     274
# 2             400  /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 3             400  /PETCT_846c1af245-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 4             400  /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558
# ...           ...                                                ...     ...
# 997           400  /PETCT_193dea6ac7-1.3.6.1.4.1.14519.5.2.1.4219...     242
# 998           400  /PETCT_80ccbdadf9-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 999           400  /PETCT_3bce0eb7aa-1.3.6.1.4.1.14519.5.2.1.4219...     303
# 1000          400  /PETCT_3ba0277c0c-1.3.6.1.4.1.14519.5.2.1.4219...     308
# 1001          400  /PETCT_48a34ccdf0-1.3.6.1.4.1.14519.5.2.1.4219...     326
#
#       width
# 0       400
# 1       400
# 2       400
# 3       400
# 4       400
# ...     ...
# 997     400
# 998     400
# 999     400
# 1000    400
# 1001    400
#
# [1002 rows x 9 columns]

# %%
data_df.diagnosis.value_counts()
# Out:
# diagnosis
# POSITIVE    501
# NEGATIVE    501
# Name: count, dtype: int64

# %%
col_names = data_df.columns.to_list()
col_names[0] = "imageId"
col_names
# Out:
# ['imageId',
#  'Subject ID',
#  'Study UID',
#  'diagnosis',
#  'sliceNum',
#  'totalSlices',
#  'filePath',
#  'height',
#  'width']

# %%
data_df.columns = col_names
data_df.head()
# Out:
#    imageId        Subject ID  \
# 0        0  PETCT_f21755a99b
# 1        1  PETCT_176bdc5388
# 2        2  PETCT_605369e88d
# 3        3  PETCT_846c1af245
# 4        4  PETCT_7ce196485f
#
#                                            Study UID diagnosis  sliceNum  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE       196
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.908703633623...  NEGATIVE       196
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE       207
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.158562682786...  NEGATIVE       207
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE       215
#
#    totalSlices                                           filePath  height  \
# 0          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 1          400  /PETCT_176bdc5388-1.3.6.1.4.1.14519.5.2.1.4219...     274
# 2          400  /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 3          400  /PETCT_846c1af245-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 4          400  /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558
#
#    width
# 0    400
# 1    400
# 2    400
# 3    400
# 4    400

# %%
# new height will be based on the mean value
data_df.height.mean()
# Out:
# 350.74251497005986

# %%
@dataclass(frozen=True)
class ImageResizeConfig:
    height: int = 350
    width: int = 400

# %%
def pre_process_and_export_record(row):
    image_path = DatasetConfig.DATA_ROOT_TARGET + row["filePath"]
    img = cv2.imread(image_path)
    img = cv2.resize(img, (ImageResizeConfig.height, ImageResizeConfig.width))
    img = cv2.normalize(img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
    
    img_class = "0" if row.diagnosis == "NEGATIVE" else "1"
    
    destination_path = f"{DatasetConfig.DATA_ROOT_TARGET}/{row.subset}/{img_class}"
    pathlib.Path(destination_path).mkdir(parents=True, exist_ok=True)
    destination_path = f"{destination_path}/{row.imageId}.png"
    
    cv2.imwrite(destination_path,img)

# %%
data_df["subset"] = None

# %%
data_df.head()
# Out:
#    imageId        Subject ID  \
# 0        0  PETCT_f21755a99b
# 1        1  PETCT_176bdc5388
# 2        2  PETCT_605369e88d
# 3        3  PETCT_846c1af245
# 4        4  PETCT_7ce196485f
#
#                                            Study UID diagnosis  sliceNum  \
# 0  1.3.6.1.4.1.14519.5.2.1.4219.6651.631135993785...  POSITIVE       196
# 1  1.3.6.1.4.1.14519.5.2.1.4219.6651.908703633623...  NEGATIVE       196
# 2  1.3.6.1.4.1.14519.5.2.1.4219.6651.161111150372...  POSITIVE       207
# 3  1.3.6.1.4.1.14519.5.2.1.4219.6651.158562682786...  NEGATIVE       207
# 4  1.3.6.1.4.1.14519.5.2.1.4219.6651.226902065774...  POSITIVE       215
#
#    totalSlices                                           filePath  height  \
# 0          400  /PETCT_f21755a99b-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 1          400  /PETCT_176bdc5388-1.3.6.1.4.1.14519.5.2.1.4219...     274
# 2          400  /PETCT_605369e88d-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 3          400  /PETCT_846c1af245-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 4          400  /PETCT_7ce196485f-1.3.6.1.4.1.14519.5.2.1.4219...     558
#
#    width subset
# 0    400   None
# 1    400   None
# 2    400   None
# 3    400   None
# 4    400   None

# %%
train_df = pd.concat([data_df[data_df.diagnosis == "POSITIVE"].sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE),
           data_df[data_df.diagnosis == "NEGATIVE"].sample(frac=0.8, random_state=DatasetConfig.SEED_VALUE)]
         ).sample(frac=1, random_state=DatasetConfig.SEED_VALUE)
train_df
# Out:
#      imageId        Subject ID  \
# 960      960  PETCT_ed9fa4eff1
# 576      576  PETCT_1472967bef
# 430      430  PETCT_32aa845af1
# 599      599  PETCT_d3f13dff4b
# 894      894  PETCT_5255c79083
# ..       ...               ...
# 267      267  PETCT_e344879c2e
# 707      707  PETCT_b0e002e974
# 974      974  PETCT_9c9a347388
# 830      830  PETCT_fde79b6aa9
# 976      976  PETCT_790246c76c
#
#                                              Study UID diagnosis  sliceNum  \
# 960  1.3.6.1.4.1.14519.5.2.1.4219.6651.250121439180...  POSITIVE       165
# 576  1.3.6.1.4.1.14519.5.2.1.4219.6651.345018069062...  POSITIVE       193
# 430  1.3.6.1.4.1.14519.5.2.1.4219.6651.111627576176...  POSITIVE       214
# 599  1.3.6.1.4.1.14519.5.2.1.4219.6651.225424126913...  NEGATIVE       210
# 894  1.3.6.1.4.1.14519.5.2.1.4219.6651.309952339235...  POSITIVE       193
# ..                                                 ...       ...       ...
# 267  1.3.6.1.4.1.14519.5.2.1.4219.6651.216424922409...  NEGATIVE       163
# 707  1.3.6.1.4.1.14519.5.2.1.4219.6651.222462861073...  NEGATIVE       201
# 974  1.3.6.1.4.1.14519.5.2.1.4219.6651.877463610141...  POSITIVE       194
# 830  1.3.6.1.4.1.14519.5.2.1.4219.6651.960887139192...  POSITIVE       202
# 976  1.3.6.1.4.1.14519.5.2.1.4219.6651.124180203357...  POSITIVE       213
#
#      totalSlices                                           filePath  height  \
# 960          400  /PETCT_ed9fa4eff1-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 576          400  /PETCT_1472967bef-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 430          400  /PETCT_32aa845af1-1.3.6.1.4.1.14519.5.2.1.4219...     624
# 599          400  /PETCT_d3f13dff4b-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 894          400  /PETCT_5255c79083-1.3.6.1.4.1.14519.5.2.1.4219...     284
# ..           ...                                                ...     ...
# 267          400  /PETCT_e344879c2e-1.3.6.1.4.1.14519.5.2.1.4219...     318
# 707          400  /PETCT_b0e002e974-1.3.6.1.4.1.14519.5.2.1.4219...     368
# 974          400  /PETCT_9c9a347388-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 830          400  /PETCT_fde79b6aa9-1.3.6.1.4.1.14519.5.2.1.4219...     577
# 976          400  /PETCT_790246c76c-1.3.6.1.4.1.14519.5.2.1.4219...     284
#
#      width subset
# 960    400   None
# 576    400   None
# 430    400   None
# 599    400   None
# 894    400   None
# ..     ...    ...
# 267    400   None
# 707    400   None
# 974    400   None
# 830    400   None
# 976    400   None
#
# [802 rows x 10 columns]

# %%
test_df = data_df.drop(train_df.index, inplace=False).sample(frac=1, random_state=DatasetConfig.SEED_VALUE)
test_df
# Out:
#      imageId        Subject ID  \
# 424      424  PETCT_581fa95eb0
# 277      277  PETCT_1a90052cb2
# 880      880  PETCT_23ed525e82
# 978      978  PETCT_ac11b344b6
# 294      294  PETCT_dac5cd2a4d
# ..       ...               ...
# 283      283  PETCT_1cb2d26a19
# 352      352  PETCT_b6a3c72db6
# 730      730  PETCT_a4cd2b10de
# 861      861  PETCT_c2ffda4725
# 968      968  PETCT_ec581d49ef
#
#                                              Study UID diagnosis  sliceNum  \
# 424  1.3.6.1.4.1.14519.5.2.1.4219.6651.417489576678...  POSITIVE       180
# 277  1.3.6.1.4.1.14519.5.2.1.4219.6651.326921868047...  NEGATIVE       180
# 880  1.3.6.1.4.1.14519.5.2.1.4219.6651.319700747490...  POSITIVE       209
# 978  1.3.6.1.4.1.14519.5.2.1.4219.6651.185972599218...  POSITIVE       154
# 294  1.3.6.1.4.1.14519.5.2.1.4219.6651.115036314520...  POSITIVE       198
# ..                                                 ...       ...       ...
# 283  1.3.6.1.4.1.14519.5.2.1.4219.6651.167566570259...  NEGATIVE       188
# 352  1.3.6.1.4.1.14519.5.2.1.4219.6651.332328809191...  POSITIVE       173
# 730  1.3.6.1.4.1.14519.5.2.1.4219.6651.162317265485...  POSITIVE       167
# 861  1.3.6.1.4.1.14519.5.2.1.4219.6651.149257052777...  NEGATIVE       198
# 968  1.3.6.1.4.1.14519.5.2.1.4219.6651.891893183165...  POSITIVE       212
#
#      totalSlices                                           filePath  height  \
# 424          400  /PETCT_581fa95eb0-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 277          400  /PETCT_1a90052cb2-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 880          400  /PETCT_23ed525e82-1.3.6.1.4.1.14519.5.2.1.4219...     577
# 978          400  /PETCT_ac11b344b6-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 294          400  /PETCT_dac5cd2a4d-1.3.6.1.4.1.14519.5.2.1.4219...     326
# ..           ...                                                ...     ...
# 283          400  /PETCT_1cb2d26a19-1.3.6.1.4.1.14519.5.2.1.4219...     330
# 352          400  /PETCT_b6a3c72db6-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 730          400  /PETCT_a4cd2b10de-1.3.6.1.4.1.14519.5.2.1.4219...     368
# 861          400  /PETCT_c2ffda4725-1.3.6.1.4.1.14519.5.2.1.4219...     242
# 968          400  /PETCT_ec581d49ef-1.3.6.1.4.1.14519.5.2.1.4219...     326
#
#      width subset
# 424    400   None
# 277    400   None
# 880    400   None
# 978    400   None
# 294    400   None
# ..     ...    ...
# 283    400   None
# 352    400   None
# 730    400   None
# 861    400   None
# 968    400   None
#
# [200 rows x 10 columns]

# %%
val_df = pd.concat([train_df[train_df.diagnosis == "POSITIVE"].sample(frac=0.1, random_state=DatasetConfig.SEED_VALUE),
           train_df[train_df.diagnosis == "NEGATIVE"].sample(frac=0.1, random_state=DatasetConfig.SEED_VALUE)]
         ).sample(frac=1, random_state=DatasetConfig.SEED_VALUE)
val_df
# Out:
#      imageId        Subject ID  \
# 233      233  PETCT_e5d50c5569
# 976      976  PETCT_790246c76c
# 317      317  PETCT_a1d93ebc74
# 469      469  PETCT_ca9570a0eb
# 474      474  PETCT_a3df01d3a3
# ..       ...               ...
# 866      866  PETCT_ca47fe5e7d
# 951      951  PETCT_4a72eeb991
# 208      208  PETCT_802f19931c
# 260      260  PETCT_b510436d83
# 707      707  PETCT_b0e002e974
#
#                                              Study UID diagnosis  sliceNum  \
# 233  1.3.6.1.4.1.14519.5.2.1.4219.6651.219869499045...  NEGATIVE       217
# 976  1.3.6.1.4.1.14519.5.2.1.4219.6651.124180203357...  POSITIVE       213
# 317  1.3.6.1.4.1.14519.5.2.1.4219.6651.864336233005...  NEGATIVE       178
# 469  1.3.6.1.4.1.14519.5.2.1.4219.6651.944693887076...  NEGATIVE       200
# 474  1.3.6.1.4.1.14519.5.2.1.4219.6651.255296228951...  POSITIVE       194
# ..                                                 ...       ...       ...
# 866  1.3.6.1.4.1.14519.5.2.1.4219.6651.184188057439...  POSITIVE       221
# 951  1.3.6.1.4.1.14519.5.2.1.4219.6651.252474349422...  NEGATIVE       176
# 208  1.3.6.1.4.1.14519.5.2.1.4219.6651.415089458243...  POSITIVE       189
# 260  1.3.6.1.4.1.14519.5.2.1.4219.6651.318475350317...  POSITIVE       222
# 707  1.3.6.1.4.1.14519.5.2.1.4219.6651.222462861073...  NEGATIVE       201
#
#      totalSlices                                           filePath  height  \
# 233          400  /PETCT_e5d50c5569-1.3.6.1.4.1.14519.5.2.1.4219...     338
# 976          400  /PETCT_790246c76c-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 317          400  /PETCT_a1d93ebc74-1.3.6.1.4.1.14519.5.2.1.4219...     535
# 469          400  /PETCT_ca9570a0eb-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 474          400  /PETCT_a3df01d3a3-1.3.6.1.4.1.14519.5.2.1.4219...     326
# ..           ...                                                ...     ...
# 866          400  /PETCT_ca47fe5e7d-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 951          400  /PETCT_4a72eeb991-1.3.6.1.4.1.14519.5.2.1.4219...     536
# 208          400  /PETCT_802f19931c-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 260          400  /PETCT_b510436d83-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 707          400  /PETCT_b0e002e974-1.3.6.1.4.1.14519.5.2.1.4219...     368
#
#      width subset
# 233    400   None
# 976    400   None
# 317    400   None
# 469    400   None
# 474    400   None
# ..     ...    ...
# 866    400   None
# 951    400   None
# 208    400   None
# 260    400   None
# 707    400   None
#
# [80 rows x 10 columns]

# %%
train_df = train_df.drop(val_df.index, inplace=False)
train_df
# Out:
#      imageId        Subject ID  \
# 960      960  PETCT_ed9fa4eff1
# 576      576  PETCT_1472967bef
# 430      430  PETCT_32aa845af1
# 599      599  PETCT_d3f13dff4b
# 894      894  PETCT_5255c79083
# ..       ...               ...
# 832      832  PETCT_e77c5fca12
# 883      883  PETCT_63464433c8
# 267      267  PETCT_e344879c2e
# 974      974  PETCT_9c9a347388
# 830      830  PETCT_fde79b6aa9
#
#                                              Study UID diagnosis  sliceNum  \
# 960  1.3.6.1.4.1.14519.5.2.1.4219.6651.250121439180...  POSITIVE       165
# 576  1.3.6.1.4.1.14519.5.2.1.4219.6651.345018069062...  POSITIVE       193
# 430  1.3.6.1.4.1.14519.5.2.1.4219.6651.111627576176...  POSITIVE       214
# 599  1.3.6.1.4.1.14519.5.2.1.4219.6651.225424126913...  NEGATIVE       210
# 894  1.3.6.1.4.1.14519.5.2.1.4219.6651.309952339235...  POSITIVE       193
# ..                                                 ...       ...       ...
# 832  1.3.6.1.4.1.14519.5.2.1.4219.6651.290078519905...  POSITIVE       168
# 883  1.3.6.1.4.1.14519.5.2.1.4219.6651.988752465833...  NEGATIVE       187
# 267  1.3.6.1.4.1.14519.5.2.1.4219.6651.216424922409...  NEGATIVE       163
# 974  1.3.6.1.4.1.14519.5.2.1.4219.6651.877463610141...  POSITIVE       194
# 830  1.3.6.1.4.1.14519.5.2.1.4219.6651.960887139192...  POSITIVE       202
#
#      totalSlices                                           filePath  height  \
# 960          400  /PETCT_ed9fa4eff1-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 576          400  /PETCT_1472967bef-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 430          400  /PETCT_32aa845af1-1.3.6.1.4.1.14519.5.2.1.4219...     624
# 599          400  /PETCT_d3f13dff4b-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 894          400  /PETCT_5255c79083-1.3.6.1.4.1.14519.5.2.1.4219...     284
# ..           ...                                                ...     ...
# 832          400  /PETCT_e77c5fca12-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 883          400  /PETCT_63464433c8-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 267          400  /PETCT_e344879c2e-1.3.6.1.4.1.14519.5.2.1.4219...     318
# 974          400  /PETCT_9c9a347388-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 830          400  /PETCT_fde79b6aa9-1.3.6.1.4.1.14519.5.2.1.4219...     577
#
#      width subset
# 960    400   None
# 576    400   None
# 430    400   None
# 599    400   None
# 894    400   None
# ..     ...    ...
# 832    400   None
# 883    400   None
# 267    400   None
# 974    400   None
# 830    400   None
#
# [722 rows x 10 columns]

# %%
train_df.diagnosis.value_counts()
# Out:
# diagnosis
# POSITIVE    361
# NEGATIVE    361
# Name: count, dtype: int64

# %%
val_df.diagnosis.value_counts()
# Out:
# diagnosis
# NEGATIVE    40
# POSITIVE    40
# Name: count, dtype: int64

# %%
test_df.diagnosis.value_counts()
# Out:
# diagnosis
# POSITIVE    100
# NEGATIVE    100
# Name: count, dtype: int64

# %%
train_df.subset = "Train"
val_df.subset = "Valid"
test_df.subset = "Test"

# %%
full_data = pd.concat([train_df, val_df, test_df]).sample(frac=1,random_state=DatasetConfig.SEED_VALUE)
full_data
# Out:
#      imageId        Subject ID  \
# 727      727  PETCT_b66ba83594
# 940      940  PETCT_63dd9503eb
# 254      254  PETCT_2e44706eaf
# 678      678  PETCT_17d334cb6c
# 247      247  PETCT_b663adb148
# ..       ...               ...
# 180      180  PETCT_2202a936e0
# 154      154  PETCT_f9c4d4f9ab
# 259      259  PETCT_562294be56
# 756      756  PETCT_963a71819a
# 406      406  PETCT_ede28cc3c2
#
#                                              Study UID diagnosis  sliceNum  \
# 727  1.3.6.1.4.1.14519.5.2.1.4219.6651.242835223533...  NEGATIVE       212
# 940  1.3.6.1.4.1.14519.5.2.1.4219.6651.316550527203...  POSITIVE       201
# 254  1.3.6.1.4.1.14519.5.2.1.4219.6651.217378964956...  POSITIVE       162
# 678  1.3.6.1.4.1.14519.5.2.1.4219.6651.143961978386...  POSITIVE       191
# 247  1.3.6.1.4.1.14519.5.2.1.4219.6651.316934660962...  NEGATIVE       202
# ..                                                 ...       ...       ...
# 180  1.3.6.1.4.1.14519.5.2.1.4219.6651.248146545971...  POSITIVE       194
# 154  1.3.6.1.4.1.14519.5.2.1.4219.6651.145948856856...  POSITIVE       174
# 259  1.3.6.1.4.1.14519.5.2.1.4219.6651.222057902209...  NEGATIVE       155
# 756  1.3.6.1.4.1.14519.5.2.1.4219.6651.718616482864...  POSITIVE       191
# 406  1.3.6.1.4.1.14519.5.2.1.4219.6651.204402777024...  POSITIVE       189
#
#      totalSlices                                           filePath  height  \
# 727          400  /PETCT_b66ba83594-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 940          400  /PETCT_63dd9503eb-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 254          400  /PETCT_2e44706eaf-1.3.6.1.4.1.14519.5.2.1.4219...     493
# 678          400  /PETCT_17d334cb6c-1.3.6.1.4.1.14519.5.2.1.4219...     326
# 247          400  /PETCT_b663adb148-1.3.6.1.4.1.14519.5.2.1.4219...     589
# ..           ...                                                ...     ...
# 180          400  /PETCT_2202a936e0-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 154          400  /PETCT_f9c4d4f9ab-1.3.6.1.4.1.14519.5.2.1.4219...     397
# 259          400  /PETCT_562294be56-1.3.6.1.4.1.14519.5.2.1.4219...     493
# 756          400  /PETCT_963a71819a-1.3.6.1.4.1.14519.5.2.1.4219...     284
# 406          400  /PETCT_ede28cc3c2-1.3.6.1.4.1.14519.5.2.1.4219...     284
#
#      width subset
# 727    400  Train
# 940    400   Test
# 254    400   Test
# 678    400  Train
# 247    400  Train
# ..     ...    ...
# 180    400  Train
# 154    400   Test
# 259    400   Test
# 756    400   Test
# 406    400   Test
#
# [1002 rows x 10 columns]

# %%
from tqdm import tqdm

# %%
for index, row in tqdm(full_data.iterrows(), total=len(full_data)):
    pre_process_and_export_record(row)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1002/1002 [00:03<00:00, 293.60it/s]
